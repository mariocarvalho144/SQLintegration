# %%
pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in c:\users\mário\anaconda3\lib\site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc

dados_conexao = (
    "Driver={SQL Server};"
    "Server=MarioCarvalho;"
    "Database=PythonSQL;"
)

conexao = pyodbc.connect(dados_conexao);
print("Conexão bem sucedida")
# Out:
# Conexão bem sucedida

# %%
cursor = conexao.cursor()
id = 4
data = "01/12/1999"
cliente = "Carlos"
produto = "Mouse"
preco = 20
quantidade = 3

comando = f"""INSERT INTO Vendas(id_venda,data_venda,cliente,produto,preco,quantidade)
VALUES
	({id},'{data}','{cliente}','{produto}',{preco},{quantidade})"""

cursor.execute(comando)

cursor.commit()
